# %%
# install necessary packages to allow you to connect and locally access your database in your local machine
# !pip -q install pymysql sqlalchemy ipython-sql

# %%
# !pip install "sqlalchemy<2.0" -q

# %%
pip install prettytable==3.6.0 -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# prepare SQL environment
# %load_ext sql

# %%
#mysql connection string
# %sql mysql+pymysql://root:your_workbench_password@127.0.0.1:3306/your_database_name
# Out:
# 'Connected: root@md_water_services'
